# %%
import pandas as pd 
import numpy as np

# %%
translated = np.array([])
for i in range(1,10):
    df = pd.read_csv(f'../Data/translated_{i}.csv', index_col=0)
    translated = np.append(translated, df['translated'].values)

# %%
df = pd.read_csv('../Data/data.csv')

# %%
df['translated'] = translated

# %%
pd.set_option('display.max_colwidth', None)

# %%
df[['reviewContent' ,'translated']].head(5)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df.to_csv('../Data/new_df.csv')

# %%
fake_df = df.loc[df['flagged'] == 'Y']

# %%
real_df = df.loc[df['flagged'] == 'N']

# %%
fake_df[['reviewContent' ,'translated']].head(5)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
real_df[['reviewContent' ,'translated']].head(5)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df[['reviewContent' ,'translated']].to_csv('../Data/compaired.csv')

# %%
df['reviewContent'] = translated

# %%
df.drop(columns=['translated'], inplace=True)

# %%
df.to_csv('../Data/thai_df.csv')
